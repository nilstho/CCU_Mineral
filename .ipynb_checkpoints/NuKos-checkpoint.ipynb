# %% [markdown]
# # Importing packages

# %%
from brightway2 import *
import os               # to use "operating system dependent functionality"
import numpy as np      # "the fundamental package for scientific computing with Python"
import pandas as pd     # "high-performance, easy-to-use data structures and data analysis tools" for Python
import matplotlib as mpl
import matplotlib.pyplot as plt
import bw2calc as bc
import seaborn as sns
import textwrap
# %matplotlib inline

# %% [markdown]
# # Set project

# %%
projects.set_current('Nukos_Meta_LCA')

# %%
del databases['Nukos_BG']
del databases['Nukos_FG_pess']
del databases['Nukos_FG_real']
del databases['Nukos_FG_opt']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15752/1891003670.py in <module>
# ----> 1 del databases['Nukos_BG']
#       2 del databases['Nukos_FG_pess']
#       3 del databases['Nukos_FG_real']
#       4 del databases['Nukos_FG_opt']
#
# ~\Anaconda3\envs\bw2\lib\site-packages\bw2data\project.py in writable_project(wrapped, instance, args, kwargs)
#     354     if projects.read_only:
#     355         raise ReadOnlyProject(READ_ONLY_PROJECT)
# --> 356     return wrapped(*args, **kwargs)
#
# ~\Anaconda3\envs\bw2\lib\site-packages\bw2data\meta.py in __delitem__(self, name)
#     129             pass
#     130
# --> 131         super(Databases, self).__delitem__(name)
#     132
#     133
#
# ~\Anaconda3\envs\bw2\lib\site-packages\bw2data\serialization.py in __delitem__(self, name)
#     174
#     175     def __delitem__(self, name):
# --> 176         del self.data[name]
#     177         self.flush()
#     178
#
# KeyError: 'Nukos_BG'

# %%
databases
# Out:
# Databases dictionary with 4 object(s):
# 	Example
# 	biosphere3
# 	ecoinvent 3.7.1 cutoff
# 	super_db_2021-10-06

# %% [markdown]
# # Import biosphere3 and ecoinvent

# %%
# Import the biosphere3 database
bw2setup()  # This will take some time
# Out:
# Biosphere database already present!!! No setup is needed

# %%
# Import ecoinvent

# You need to change the line below with the directory where you have saved ecoinvent
ei371dir = "/Users/niltho/OneDrive - Danmarks Tekniske Universitet/Dokumenter/BW2/ecoinvent/ecoinvent 3.7.1_cutoff_ecoSpold02/datasets"

if 'ecoinvent 3.7.1 cutoff' in databases:
    print("Database has already been imported")
else:
    ei371 = SingleOutputEcospold2Importer(ei371dir, 'ecoinvent 3.7.1 cutoff') # You can give it another name of course
    ei371.apply_strategies()
    ei371.statistics()
    ei371.write_database() # This will take some time.
# Out:
# Database has already been imported

# %%
databases
# Out:
# Databases dictionary with 4 object(s):
# 	Example
# 	biosphere3
# 	ecoinvent 3.7.1 cutoff
# 	super_db_2021-10-06

# %% [markdown]
# ## Search in ecoinvent

# %%
eidb = Database('ecoinvent 3.7.1 cutoff')

# %%
for activity in eidb.search(('glycerine production, from epichlorohydrin')):
    print(activity)
    print(activity['code'])
# Out:
# 'glycerine production, from epichlorohydrin' (kilogram, RER, None)
# 7429eae8bcbdaeac6335d75d2007367d
# 'glycerine production, from epichlorohydrin' (kilogram, RoW, None)
# 045e311251a5c514560f07951e001e3d

# %%
for activity in eidb.search(('market for car'), filter={"location" : 'GLO'}):
    print(activity)
    print(activity['code'])
# Out:
# Excluding 45 filtered results
# 'market for passenger car maintenance' (unit, GLO, None)
# a1f2fd824bdc433f31a29e167b627940
# 'market for glider, passenger car' (kilogram, GLO, None)
# 276a68be4d3fe087b6e367daeb4274e5
# 'market for passenger car, diesel' (kilogram, GLO, None)
# fd99291083977f5a4cdc7c874c2d1dbe
# 'market for used glider, passenger car' (kilogram, GLO, None)
# 1cb1b855dccc83799fcff52ef2278aba
# 'market for converter, for electric passenger car' (kilogram, GLO, None)
# fdf88418483eb926a8436b7fe80aca8d
# 'market for powertrain, for electric passenger car' (kilogram, GLO, None)
# 2323ef1cb406164e58f9b17ce15e5b83
# 'market for charger, electric passenger car' (kilogram, GLO, None)
# 028f5078f0d6aadb1b87f44526a408a8
# 'market for transport, passenger car, electric' (kilometer, GLO, None)
# eed9ad8d107b9bc357d1ffdd605d4d0d
# 'market for inverter, for electric passenger car' (kilogram, GLO, None)
# 4ee9a6c6fdd409cf4b30074640ab14a2
# 'market for brake wear emissions, passenger car' (kilogram, GLO, None)
# 55dab20741ec517162c637ee3de62314
# 'market for passenger car, electric, without battery' (kilogram, GLO, None)
# a88528bba51c9c380ebfe139d09c288e
# 'market for road wear emissions, passenger car' (kilogram, GLO, None)
# ba14982387bf519b5d03ecd954911a76
# 'market for passenger car, petrol/natural gas' (kilogram, GLO, None)
# f106d1e93658da74b9cda929ad02b2ae
# 'market for tyre wear emissions, passenger car' (kilogram, GLO, None)
# bc30049aa95f1ca8032602e6b8ba1f99
# 'market for internal combustion engine, passenger car' (kilogram, GLO, None)
# 555bc42da68ea4177054f45d41d786c1
# 'market for electric motor, electric passenger car' (kilogram, GLO, None)
# 899a0d59f9a4de6a742fb0b532d173ef
# 'market for maintenance, passenger car, electric, without battery' (unit, GLO, None)
# 9d04de42b4afe3e56cb6c1128f2a504c
# 'market for used internal combustion engine, passenger car' (kilogram, GLO, None)
# 23e54740d2fb6310f3a10c7183060862
# 'market for power distribution unit, for electric passenger car' (kilogram, GLO, None)
# 0aec7b8b05c49b7fa6db872c18139d01
# 'market for manual dismantling of used electric passenger car' (unit, GLO, None)
# b8cad98d4e30ac3fc8ffabbdb9c4bac0
# 'market for transport, passenger car, small size, petrol, EURO 5' (kilometer, GLO, None)
# 55ddce4bf8e93154722477a2c3ad8563
# 'market for transport, passenger car, large size, diesel, EURO 4' (kilometer, GLO, None)
# 029ce66fedfd5bb92b0ff1c3501235e8
# 'market for transport, passenger car, large size, petrol, EURO 3' (kilometer, GLO, None)
# 87d7da84b644783ca27571885e42167d
# 'market for transport, passenger car, medium size, diesel, EURO 4' (kilometer, GLO, None)
# a37a82709e8995af78291ae5dc7579b7
# 'market for transport, passenger car, large size, diesel, EURO 3' (kilometer, GLO, None)
# 7f21f5b836f0d475918cb831321caca2

# %%
my_act = eidb.get('7429eae8bcbdaeac6335d75d2007367d')
my_act._data
# Out:
# {'comment': 'Glycerine is produced by reacting epichlorohydrin with a 10% sodium hydroxide aqueous solution\n[This dataset was already contained in the ecoinvent database version 2. It was not individually updated during the transfer to ecoinvent version 3. Life Cycle Impact Assessment results may still have changed, as they are affected by changes in the supply chain, i.e. in other datasets. This dataset was generated following the ecoinvent quality guidelines for version 2. It may have been subject to central changes described in the ecoinvent version 3 change report (http://www.ecoinvent.org/database/ecoinvent-version-3/reports-of-changes/), and the results of the central updates were reviewed extensively. The changes added e.g. consistent water flows and other information throughout the database. The documentation of this dataset can be found in the ecoinvent reports of version 2, which are still available via the ecoinvent website. The change report linked above covers all central changes that were made during the conversion process.]\nGeography:  RER\nTechnology:  based on industry data in the US and Europe',
#  'classifications': [('ISIC rev.4 ecoinvent',
#    '2011:Manufacture of basic chemicals'),
#   ('EcoSpold01Categories', 'chemicals/organics'),
#   ('CPC', '34570: Glycerol')],
#  'activity type': 'ordinary transforming activity',
#  'activity': 'b355eb5d-5389-45c4-9ba9-63637ffe3d53',
#  'database': 'ecoinvent 3.7.1 cutoff',
#  'filename': 'b355eb5d-5389-45c4-9ba9-63637ffe3d53_3d3268fa-3c9e-43e0-be88-3dfd53718719.spold',
#  'location': 'RER',
#  'name': 'glycerine production, from epichlorohydrin',
#  'synonyms': [],
#  'parameters': [{'description': 'fraction, water, completely softened, to air',
#    'id': 'a6208a3b-d42f-476b-b52d-f12a68ecb755',
#    'unit': 'dimensionless',
#    'comment': 'Calculated value. See comment in the other parametres present in this dataset. Water, completely softened is considered to be always used as process water, thus process water fractions to air are applied to all water, completely softened input flows to calculate the amount of water consumed in the processes.',
#    'amount': 0.205,
#    'pedigree': {'reliability': 4,
#     'completeness': 4,
#     'temporal correlation': 3,
#     'geographical correlation': 2,
#     'further technological correlation': 4},
#    'uncertainty type': 2,
#    'loc': -1.585,
#    'scale': 0.30335622624235026,
#    'scale without pedigree': 0.2,
#    'name': 'fraction_WCS_to_air'},
#   {'description': 'fraction, process water, to air',
#    'id': 'daadf2d4-7bbb-4f69-8ab5-58df4c1685eb',
#    'unit': 'dimensionless',
#    'comment': 'Literature value (Statistics Canada, 2007 & Shaffer, K.H., 2008, Consumptive water use in the Great Lakes Basin, USGS) (Vionnet, S., Quantis Water Database - Technical Report, 2012).',
#    'amount': 0.205,
#    'pedigree': {'reliability': 4,
#     'completeness': 4,
#     'temporal correlation': 3,
#     'geographical correlation': 2,
#     'further technological correlation': 4},
#    'uncertainty type': 2,
#    'loc': -1.585,
#    'scale': 0.30335622624235026,
#    'scale without pedigree': 0.2,
#    'name': 'fraction_PW_to_air'}],
#  'authors': {'data entry': {'name': 'Mike Chudacoff',
#    'email': 'chudacoff@oekoscience.ch'},
#   'data generator': {'name': 'Mike Chudacoff',
#    'email': 'chudacoff@oekoscience.ch'}},
#  'type': 'process',
#  'reference product': 'glycerine',
#  'flow': '3d3268fa-3c9e-43e0-be88-3dfd53718719',
#  'unit': 'kilogram',
#  'production amount': 1.0,
#  'code': '7429eae8bcbdaeac6335d75d2007367d'}

# %%
my_act.exchanges()

# %%
for i in list(my_act.exchanges()):  # Epxlore the activity as usual
    print(i['type'])
    print(i)
    print(i['input'])
    print('-------')
# Out:
# production
# Exchange: 1.0 kilogram 'glycerine production, from epichlorohydrin' (kilogram, RER, None) to 'glycerine production, from epichlorohydrin' (kilogram, RER, None)>
# ('ecoinvent 3.7.1 cutoff', '7429eae8bcbdaeac6335d75d2007367d')
# 160000000.0
# -------
# technosphere
# Exchange: 3.9 kilogram 'market for water, completely softened' (kilogram, RER, None) to 'glycerine production, from epichlorohydrin' (kilogram, RER, None)>
# ('ecoinvent 3.7.1 cutoff', '2bb7120123d398b6570720018ef6b23c')
# 0.0
# -------
# technosphere
# Exchange: 3.932334 megajoule 'market group for heat, district or industrial, other than natural gas' (megajoule, RER, None) to 'glycerine production, from epichlorohydrin' (kilogram, RER, None)>
# ('ecoinvent 3.7.1 cutoff', '17fa23f6724c341dda56bc27076da6f3')
# 0.0
# -------
# technosphere
# Exchange: 0.44 kilogram 'market for sodium hydroxide, without water, in 50% solution state' (kilogram, GLO, None) to 'glycerine production, from epichlorohydrin' (kilogram, RER, None)>
# ('ecoinvent 3.7.1 cutoff', '221004dd37d72645d76bf3178c93a95b')
# 0.0
# -------
# technosphere
# Exchange: 0.0815016 kilowatt hour 'market group for electricity, medium voltage' (kilowatt hour, RER, None) to 'glycerine production, from epichlorohydrin' (kilogram, RER, None)>
# ('ecoinvent 3.7.1 cutoff', '60d81c7db92e925d5cbd662c4063d9d3')
# 0.0
# -------
# technosphere
# Exchange: 4e-10 unit 'chemical factory construction, organics' (unit, RER, None) to 'glycerine production, from epichlorohydrin' (kilogram, RER, None)>
# ('ecoinvent 3.7.1 cutoff', '03b22c2ecc9399265f1e39e6aeca93bb')
# 0.0
# -------
# technosphere
# Exchange: 1.015 kilogram 'market for epichlorohydrin' (kilogram, GLO, None) to 'glycerine production, from epichlorohydrin' (kilogram, RER, None)>
# ('ecoinvent 3.7.1 cutoff', '2c6ac7665148dba07cb9cffa9d2765e9')
# 0.0
# -------
# technosphere
# Exchange: 7.0452 megajoule 'market group for heat, district or industrial, natural gas' (megajoule, RER, None) to 'glycerine production, from epichlorohydrin' (kilogram, RER, None)>
# ('ecoinvent 3.7.1 cutoff', '02fe192c5259d8be7c67e08848436f13')
# 0.0
# -------
# technosphere
# Exchange: -0.00338392296977936 cubic meter 'market for wastewater, average' (cubic meter, Europe without Switzerland, None) to 'glycerine production, from epichlorohydrin' (kilogram, RER, None)>
# ('ecoinvent 3.7.1 cutoff', 'dd0ffd74212b04d3ad151323a85a3287')
# 600000.0
# -------
# technosphere
# Exchange: -0.000366077030220642 cubic meter 'market for wastewater, average' (cubic meter, CH, None) to 'glycerine production, from epichlorohydrin' (kilogram, RER, None)>
# ('ecoinvent 3.7.1 cutoff', 'ff1c8e1f34a25cccba366c1a2c8c47c4')
# 600000.0
# -------
# biosphere
# Exchange: 0.0007995 cubic meter 'Water' (cubic meter, None, ('air',)) to 'glycerine production, from epichlorohydrin' (kilogram, RER, None)>
# ('biosphere3', '075e433b-4be4-448e-9510-9a5029c1ce94')
# 0.0
# -------
# biosphere
# Exchange: 0.00078 kilogram 'AOX, Adsorbable Organic Halogen as Cl' (kilogram, None, ('water', 'surface water')) to 'glycerine production, from epichlorohydrin' (kilogram, RER, None)>
# ('biosphere3', 'e395a1a3-6915-4b72-a533-ff1a82fc3da1')
# 0.0
# -------
# biosphere
# Exchange: 0.0006 kilogram 'DOC, Dissolved Organic Carbon' (kilogram, None, ('water', 'surface water')) to 'glycerine production, from epichlorohydrin' (kilogram, RER, None)>
# ('biosphere3', '960c0f37-f34c-4fc1-b77c-22d8b35fd8d5')
# 0.0
# -------
# biosphere
# Exchange: 0.023 kilogram 'Sodium, ion' (kilogram, None, ('water', 'surface water')) to 'glycerine production, from epichlorohydrin' (kilogram, RER, None)>
# ('biosphere3', '1fc409bc-b8e7-48b2-92d5-2ced4aa7bae2')
# 0.0
# -------
# biosphere
# Exchange: 0.00192 kilogram 'COD, Chemical Oxygen Demand' (kilogram, None, ('water', 'surface water')) to 'glycerine production, from epichlorohydrin' (kilogram, RER, None)>
# ('biosphere3', 'fc0b5c85-3b49-42c2-a3fd-db7e57b696e3')
# 0.0
# -------
# biosphere
# Exchange: 0.00192 kilogram 'BOD5, Biological Oxygen Demand' (kilogram, None, ('water', 'surface water')) to 'glycerine production, from epichlorohydrin' (kilogram, RER, None)>
# ('biosphere3', '70d467b6-115e-43c5-add2-441de9411348')
# 0.0
# -------
# biosphere
# Exchange: 0.0006 kilogram 'TOC, Total Organic Carbon' (kilogram, None, ('water', 'surface water')) to 'glycerine production, from epichlorohydrin' (kilogram, RER, None)>
# ('biosphere3', 'f65558fb-61a1-4e48-b4f2-60d62f14b085')
# 0.0
# -------
# biosphere
# Exchange: 0.382 kilogram 'Chloride' (kilogram, None, ('water', 'surface water')) to 'glycerine production, from epichlorohydrin' (kilogram, RER, None)>
# ('biosphere3', '5e050fab-1837-4c42-b597-ed2f376f768f')
# 0.0
# -------

# %% [markdown]
# ## Search in biosphere

# %%
biodb = Database('biosphere3')

# %%
for activity in biodb.search('Molybdenum'): 
    print(activity)
    #print(activity['categories'])
    print(activity['code'])
# Out:
# 'Molybdenum' (kilogram, None, ('water',))
# fdaaef05-0d10-4032-b2e7-85cae3c7bd5c
# 'Molybdenum' (kilogram, None, ('air', 'non-urban air or from high stacks'))
# 5fa36ce3-aed0-443b-a09d-4cdf25b41995
# 'Molybdenum' (kilogram, None, ('soil',))
# 8b531ec0-ca7a-49cd-bef0-56f110112f34
# 'Molybdenum' (kilogram, None, ('air', 'lower stratosphere + upper troposphere'))
# 697e8ecf-bdbe-4857-92c9-e01960c91db7
# 'Molybdenum' (kilogram, None, ('water', 'ground-, long-term'))
# 7d3f7498-3596-478a-9fa1-72201ef94082
# 'Molybdenum' (kilogram, None, ('water', 'ground-'))
# 3822809c-cc03-469d-ac2a-9f85842f8440
# 'Molybdenum' (kilogram, None, ('water', 'surface water'))
# 442511cc-a98b-4242-9229-5736cb9a9399
# 'Molybdenum' (kilogram, None, ('air',))
# 640e30d2-3158-4a1a-82ef-fd0c72922c9a
# 'Molybdenum' (kilogram, None, ('soil', 'industrial'))
# c126f8a0-6bc4-42e6-9220-d6ccfef3f2ed
# 'Molybdenum' (kilogram, None, ('soil', 'agricultural'))
# 9cf3a683-ed3d-40e9-b039-7653e4fc9e20
# 'Molybdenum' (kilogram, None, ('air', 'low population density, long-term'))
# 35b4d818-1019-413b-b99d-d351d8a67ac4
# 'Molybdenum' (kilogram, None, ('water', 'ocean'))
# 163926e2-b4cc-42bb-ba7d-401028140985
# 'Molybdenum' (kilogram, None, ('air', 'urban air close to ground'))
# c26d4716-ce1e-43da-a662-cd9498b1e8bc
# 'Molybdenum' (kilogram, None, ('soil', 'forestry'))
# 1f3c2297-d652-468d-82e8-4fd59bf5b5b8
# 'Molybdenum-99' (kilo Becquerel, None, ('water',))
# 51961868-5152-47af-8e3c-45f31dae6519
# 'Molybdenum-99' (kilo Becquerel, None, ('water', 'ocean'))
# f8f82656-be38-4879-a28e-8d4c33d09f04
# 'Molybdenum-99' (kilo Becquerel, None, ('water', 'ground-'))
# 171528d9-6a7b-41cb-8c4c-60d2ad0955a1
# 'Molybdenum, in ground' (kilogram, None, ('natural resource', 'in ground'))
# e5a3dff5-72dc-5287-893c-597dd4a19566
# 'Molybdenum-99' (kilo Becquerel, None, ('water', 'surface water'))
# a7ea85d9-b9d1-4054-ba58-4e6bf4d858d0
# 'Molybdenum-99' (kilo Becquerel, None, ('water', 'ground-, long-term'))
# 396309cb-c6b2-4105-ab6a-a5a671f6edbf
# 'Molybdenum, 0.010% in sulfide, Mo 8.2E-3% and Cu 1.83% in crude ore, in ground' (kilogram, None, ('natural resource', 'in ground'))
# 06874cbb-2daf-4981-a55e-2c38be5b7277
# 'Molybdenum, 0.022% in sulfide, Mo 8.2E-3% and Cu 0.22% in crude ore, in ground' (kilogram, None, ('natural resource', 'in ground'))
# a76cf135-2be1-4e53-9423-9211acd100f1
# 'Molybdenum, 0.014% in sulfide, Mo 8.2E-3% and Cu 0.81% in crude ore, in ground' (kilogram, None, ('natural resource', 'in ground'))
# 5514ccd2-469f-4074-9905-529154e7f742
# 'Molybdenum, 0.025% in sulfide, Mo 8.2E-3% and Cu 0.39% in crude ore, in ground' (kilogram, None, ('natural resource', 'in ground'))
# 719def62-0941-4264-bc54-97093d847d7a
# 'Molybdenum, 0.11% in sulfide, Mo 4.1E-2% and Cu 0.36% in crude ore, in ground' (kilogram, None, ('natural resource', 'in ground'))
# eda28c96-8899-4d84-bf18-35c3f1de518e

# %%
my_exc = biodb.get('1f3c2297-d652-468d-82e8-4fd59bf5b5b8')
my_exc._data
# Out:
# 'soil'

# %% [markdown]
# ## Massimo's import routine

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Thu Aug 31 15:21:32 2017

@author: massimo
"""


import pandas as pd
import numpy as np

def lci_to_bw2(mydb):
    '''A function to convert a pd.Dataframe to a dict
    to be used as database in bw2'''
    
    act_keys_raw = list(mydb.columns[0:5])
    act_keys_bw2 = [i.replace('Activity ','') for i in act_keys_raw]
    
    exc_keys_raw = list(mydb.columns[5:])
    exc_keys_bw2 = [i.replace('Exchange ','') for i in exc_keys_raw]
    
    def exc_to_dict(df_data, some_list):
        exc_data = (pd.DataFrame(list(df_data.values), index = list(exc_keys_bw2))).T
        exc_data = exc_data.dropna(axis=1, how='any') # remove columns withouth the data
        e_values = (exc_data.values).tolist()[0]
        e_values = [(e_values[0],e_values[1])] + e_values[2:]
        some_list.append(dict(zip(list(exc_data.columns)[1:], e_values)))
        
    def act_to_dict(act_data):
        a_keys = act_keys_bw2[2:] + ['exchanges']
        return dict(zip(a_keys, act_data))
    
    def bio_to_dict(bio_data):
        b_keys = act_keys_bw2[2:]
        return dict(zip(b_keys, bio_data))
        
    
    db_keys = []
    db_values =[]
    
    for act in mydb['Activity name'].unique():
    
        sel = mydb[mydb['Activity name'] == act]
        db_key = (list(sel['Activity database'])[0], list(sel['Activity code'])[0])
        db_keys.append(db_key)
        
        if list(sel['Activity type'].unique())[0] == 'biosphere':
                    
            my_bio_data = list(sel.iloc[0,2:5].values)
            db_value = bio_to_dict(my_bio_data)
            db_values.append(db_value)
        
        else:
            my_exc = []
            for i in range(sel.shape[0]):
                exc_to_dict(sel.iloc[i,5:],my_exc)
            
            my_act_data = list(sel.iloc[0,2:5].values) + [my_exc]
            db_value = act_to_dict(my_act_data)
            db_values.append(db_value)
        
     
    bw2_db = dict(zip(db_keys, db_values))
    
    return bw2_db # We have a dict to be used as database. Perfect.

# %% [markdown]
# # Import

# %%
bgdb = pd.read_excel('Nukos_db.xlsx', sheet_name='Background_db', header = 0)
# clean up a bit
bgdb = bgdb.drop('Notes', 1)  # remove the columns not needed
bgdb['Exchange uncertainty type'] = bgdb['Exchange uncertainty type'].fillna(0).astype(int) # uncertainty as integer 
                    ### Note: (can't have the full column if there are mixed nan and values, so use zero as default)
# Create a dict that can be written as database
bw2_db = lci_to_bw2(bgdb) # Perfect.
bg_db = Database('Nukos_BG') # it works because the database name in the excel file is the same
    # shut down all other notebooks using the same project
bg_db.write(bw2_db)
# Out:
# C:\Users\niltho\AppData\Local\Temp/ipykernel_19104/552779738.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   bgdb = bgdb.drop('Notes', 1)  # remove the columns not needed
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 09/08/2021 13:59:18
#   Finished: 09/08/2021 13:59:18
#   Total time elapsed: 00:00:00
#   CPU %: 80.10
#   Memory %: 0.31

# %%
fgdb_pess = pd.read_excel('Nukos_db.xlsx', sheet_name='Foreground_db_pessimistic', header = 0)
# clean up a bit
fgdb_pess = fgdb_pess.drop('Notes', 1)  # remove the columns not needed
fgdb_pess['Exchange uncertainty type'] = fgdb_pess['Exchange uncertainty type'].fillna(0).astype(int) # uncertainty as integer 
                    ### Note: (can't have the full column if there are mixed nan and values, so use zero as default)
# Create a dict that can be written as database
bw2_db = lci_to_bw2(fgdb_pess) # Perfect.
fg_db_pess = Database('Nukos_FG_pess') # it works because the database name in the excel file is the same
    # shut down all other notebooks using the same project
fg_db_pess.write(bw2_db)
# Out:
# C:\Users\niltho\AppData\Local\Temp/ipykernel_19104/3622526434.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   fgdb_pess = fgdb_pess.drop('Notes', 1)  # remove the columns not needed
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 09/08/2021 13:59:36
#   Finished: 09/08/2021 13:59:36
#   Total time elapsed: 00:00:00
#   CPU %: 99.40
#   Memory %: 0.31

# %%
fgdb_real = pd.read_excel('Nukos_db.xlsx', sheet_name='Foreground_db_realistic', header = 0)
# clean up a bit
fgdb_real = fgdb_real.drop('Notes', 1)  # remove the columns not needed
fgdb_real['Exchange uncertainty type'] = fgdb_real['Exchange uncertainty type'].fillna(0).astype(int) # uncertainty as integer 
                    ### Note: (can't have the full column if there are mixed nan and values, so use zero as default)
# Create a dict that can be written as database
bw2_db = lci_to_bw2(fgdb_real) # Perfect.
fg_db_real = Database('Nukos_FG_real') # it works because the database name in the excel file is the same
    # shut down all other notebooks using the same project
fg_db_real.write(bw2_db)
# Out:
# C:\Users\niltho\AppData\Local\Temp/ipykernel_19104/2622637829.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   fgdb_real = fgdb_real.drop('Notes', 1)  # remove the columns not needed
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 09/08/2021 13:59:38
#   Finished: 09/08/2021 13:59:38
#   Total time elapsed: 00:00:00
#   CPU %: 125.00
#   Memory %: 0.31

# %%
fgdb_opt = pd.read_excel('Nukos_db.xlsx', sheet_name='Foreground_db_optimistic', header = 0)
# clean up a bit
fgdb_opt = fgdb_opt.drop('Notes', 1)  # remove the columns not needed
fgdb_opt['Exchange uncertainty type'] = fgdb_opt['Exchange uncertainty type'].fillna(0).astype(int) # uncertainty as integer 
                    ### Note: (can't have the full column if there are mixed nan and values, so use zero as default)
# Create a dict that can be written as database
bw2_db = lci_to_bw2(fgdb_opt) # Perfect.
fg_db_opt = Database('Nukos_FG_opt') # it works because the database name in the excel file is the same
    # shut down all other notebooks using the same project
fg_db_opt.write(bw2_db)
# Out:
# C:\Users\niltho\AppData\Local\Temp/ipykernel_19104/114796074.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   fgdb_opt = fgdb_opt.drop('Notes', 1)  # remove the columns not needed
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 09/08/2021 13:59:39
#   Finished: 09/08/2021 13:59:40
#   Total time elapsed: 00:00:00
#   CPU %: 116.40
#   Memory %: 0.31

# %%
acts_Nukos = [act['name'] for act in fg_db_pess]
acts_Nukos.sort()

# %%
ILCD = [m for m in methods if
        'ILCD 2.0' in m[0]
        and 'no LT' not in str(m)]
ILCD.sort()

# %%
ILCD
# Out:
# [('ILCD 2.0 2018 midpoint', 'climate change', 'climate change biogenic'),
#  ('ILCD 2.0 2018 midpoint', 'climate change', 'climate change fossil'),
#  ('ILCD 2.0 2018 midpoint',
#   'climate change',
#   'climate change land use and land use change'),
#  ('ILCD 2.0 2018 midpoint', 'climate change', 'climate change total'),
#  ('ILCD 2.0 2018 midpoint',
#   'ecosystem quality',
#   'freshwater and terrestrial acidification'),
#  ('ILCD 2.0 2018 midpoint', 'ecosystem quality', 'freshwater ecotoxicity'),
#  ('ILCD 2.0 2018 midpoint', 'ecosystem quality', 'freshwater eutrophication'),
#  ('ILCD 2.0 2018 midpoint', 'ecosystem quality', 'marine eutrophication'),
#  ('ILCD 2.0 2018 midpoint', 'ecosystem quality', 'terrestrial eutrophication'),
#  ('ILCD 2.0 2018 midpoint', 'human health', 'carcinogenic effects'),
#  ('ILCD 2.0 2018 midpoint', 'human health', 'ionising radiation'),
#  ('ILCD 2.0 2018 midpoint', 'human health', 'non-carcinogenic effects'),
#  ('ILCD 2.0 2018 midpoint', 'human health', 'ozone layer depletion'),
#  ('ILCD 2.0 2018 midpoint', 'human health', 'photochemical ozone creation'),
#  ('ILCD 2.0 2018 midpoint', 'human health', 'respiratory effects, inorganics'),
#  ('ILCD 2.0 2018 midpoint', 'resources', 'dissipated water'),
#  ('ILCD 2.0 2018 midpoint', 'resources', 'fossils'),
#  ('ILCD 2.0 2018 midpoint', 'resources', 'land use'),
#  ('ILCD 2.0 2018 midpoint', 'resources', 'minerals and metals')]

# %%
mymethod = ILCD[3]
mymethod
# Out:
# ('ILCD 2.0 2018 midpoint', 'climate change', 'climate change total')

# %%
test = fg_db_pess.get('Carbonation mixing 1')

E = [test]
fu = {E[0]: 1}
lca = LCA(fu, mymethod)
lca.lci()
lca.lcia()
print(fu, lca.score)
# Out:
# {'Carbonation mixing 1' (kilogram, None, None): 1} -34.70714133395514

# %%
test = bg_db.get('CEM I')

E = [test]
fu = {E[0]: 1}
lca = LCA(fu, mymethod)
lca.lci()
lca.lcia()
print(fu, lca.score)
# Out:
# {'CEM I' (kilogram, None, None): 1} 0.8784005866116208

# %%
test = eidb.get('f46be3f9ceda9863f49b7a7ed20b127e')

E = [test]
fu = {E[0]: -2.074688797}
lca = LCA(fu, mymethod)
lca.lci()
lca.lcia()
print(fu, lca.score)
# Out:
# {'market for concrete, 25-30MPa' (cubic meter, RoW, None): -2.074688797} -674.2462409774323

# %%
def dolcacalc(myact, mydemand, mymethod):
    my_fu = {myact: mydemand} 
    lca = LCA(my_fu, mymethod)
    lca.lci()
    lca.lcia()
    return lca.score

def getLCAresults(acts, database, mymethod):
    
    all_activities = []
    results = []
    for a in acts:
        act = Database(database).get(a)
        all_activities.append(act['name'])
        results.append(dolcacalc(act,1,mymethod)) # 1 stays for one unit of each process
     
    results_dict = dict(zip(all_activities, results))
    
    return results_dict

# %%
databases
# Out:
# Databases dictionary with 13 object(s):
# 	Nukos_BG
# 	Nukos_FG_opt
# 	Nukos_FG_pess
# 	Nukos_FG_real
# 	Training
# 	biosphere3
# 	ecoinvent 3.7.1 cutoff
# 	ecoinvent_remind_SSP2-Base_2020
# 	ecoinvent_remind_SSP2-Base_2030
# 	ecoinvent_remind_SSP2-Base_2040
# 	ecoinvent_remind_SSP2-Base_2050
# 	super_db_2021-08-24
# 	super_db_2021-09-06

# %%
results_ILCD = []
for m in ILCD:
    results_all_acts = getLCAresults(acts_Nukos, "Nukos_FG_pess", m) # total impact per tech
    results_ILCD.append(results_all_acts)
    
midpoint_methods_names = []
for m in ILCD:
    midpoint_methods_names.append(m)
    
LCIA_Nukos_FG_pess = pd.DataFrame(results_ILCD, index=ILCD)
LCIA_Nukos_FG_pess.head()
# Out:
#                                                     Carbonation curing 1  \
# (ILCD 2.0 2018 midpoint, climate change, climat...             -0.000088
# (ILCD 2.0 2018 midpoint, climate change, climat...             -1.885915
# (ILCD 2.0 2018 midpoint, climate change, climat...             -0.000032
# (ILCD 2.0 2018 midpoint, climate change, climat...             -1.886035
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...             -0.001889
#
#                                                     Carbonation curing 2  \
# (ILCD 2.0 2018 midpoint, climate change, climat...              0.007698
# (ILCD 2.0 2018 midpoint, climate change, climat...             -0.438303
# (ILCD 2.0 2018 midpoint, climate change, climat...              0.002986
# (ILCD 2.0 2018 midpoint, climate change, climat...             -0.427618
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...              0.005874
#
#                                                     Carbonation curing 3  \
# (ILCD 2.0 2018 midpoint, climate change, climat...              0.000378
# (ILCD 2.0 2018 midpoint, climate change, climat...             -2.031934
# (ILCD 2.0 2018 midpoint, climate change, climat...              0.000138
# (ILCD 2.0 2018 midpoint, climate change, climat...             -2.031418
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...             -0.001859
#
#                                                     Carbonation mixing 1  \
# (ILCD 2.0 2018 midpoint, climate change, climat...             -0.387292
# (ILCD 2.0 2018 midpoint, climate change, climat...            -34.199404
# (ILCD 2.0 2018 midpoint, climate change, climat...             -0.120446
# (ILCD 2.0 2018 midpoint, climate change, climat...            -34.707141
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...             -0.457773
#
#                                                     Direct aqueous carbonation 1  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.003124
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -0.348858
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.001211
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -0.344523
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                      0.003339
#
#                                                     Direct aqueous carbonation 10  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                       0.000533
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.937109
# (ILCD 2.0 2018 midpoint, climate change, climat...                       0.000203
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.936373
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                       0.000312
#
#                                                     Direct aqueous carbonation 11  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                       0.000583
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.932638
# (ILCD 2.0 2018 midpoint, climate change, climat...                       0.000223
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.931832
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                       0.000334
#
#                                                     Direct aqueous carbonation 12  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                       0.000463
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.942384
# (ILCD 2.0 2018 midpoint, climate change, climat...                       0.000177
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.941744
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                       0.000280
#
#                                                     Direct aqueous carbonation 13  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                       0.000508
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.937673
# (ILCD 2.0 2018 midpoint, climate change, climat...                       0.000194
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.936971
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                       0.000299
#
#                                                     Direct aqueous carbonation 14  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                       0.000419
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.948439
# (ILCD 2.0 2018 midpoint, climate change, climat...                       0.000160
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.947860
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                       0.000249
#
#                                                     ...  \
# (ILCD 2.0 2018 midpoint, climate change, climat...  ...
# (ILCD 2.0 2018 midpoint, climate change, climat...  ...
# (ILCD 2.0 2018 midpoint, climate change, climat...  ...
# (ILCD 2.0 2018 midpoint, climate change, climat...  ...
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...  ...
#
#                                                     Indirect aqueous carbonation 5  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -0.027633
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -2.047089
# (ILCD 2.0 2018 midpoint, climate change, climat...                        0.000712
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -2.074010
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                       -0.021083
#
#                                                     Indirect aqueous carbonation 6  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -0.027935
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -2.156387
# (ILCD 2.0 2018 midpoint, climate change, climat...                        0.000594
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -2.183727
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                       -0.021434
#
#                                                     Indirect aqueous carbonation 7  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                        0.002734
# (ILCD 2.0 2018 midpoint, climate change, climat...                        0.504271
# (ILCD 2.0 2018 midpoint, climate change, climat...                        0.001061
# (ILCD 2.0 2018 midpoint, climate change, climat...                        0.508066
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                        0.005616
#
#                                                     Indirect aqueous carbonation 8  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                        0.008929
# (ILCD 2.0 2018 midpoint, climate change, climat...                        1.175421
# (ILCD 2.0 2018 midpoint, climate change, climat...                        0.003270
# (ILCD 2.0 2018 midpoint, climate change, climat...                        1.187621
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                        0.017375
#
#                                                     Indirect aqueous carbonation 9  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                        0.000780
# (ILCD 2.0 2018 midpoint, climate change, climat...                        1.441180
# (ILCD 2.0 2018 midpoint, climate change, climat...                        0.000318
# (ILCD 2.0 2018 midpoint, climate change, climat...                        1.442278
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                        0.008004
#
#                                                     Indirect solid carbonation 1  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.000986
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -1.309595
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.000380
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -1.308229
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                     -0.000505
#
#                                                     Indirect solid carbonation 2  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.001324
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -0.381057
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.000513
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -0.379219
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                      0.003111
#
#                                                     Indirect solid carbonation 3  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.000994
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.209378
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.000384
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.210756
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                      0.003858
#
#                                                     Indirect solid carbonation 4  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.001159
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -0.403609
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.000452
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -0.401998
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                      0.002355
#
#                                                     Indirect solid carbonation 5
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.007357
# (ILCD 2.0 2018 midpoint, climate change, climat...                      2.386406
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.002865
# (ILCD 2.0 2018 midpoint, climate change, climat...                      2.396627
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                      0.013688
#
# [5 rows x 34 columns]

# %%
results_ILCD = []
for m in ILCD:
    results_all_acts = getLCAresults(acts_Nukos, "Nukos_FG_real", m) # total impact per tech
    results_ILCD.append(results_all_acts)
    
midpoint_methods_names = []
for m in ILCD:
    midpoint_methods_names.append(m)
    
LCIA_Nukos_FG_real = pd.DataFrame(results_ILCD, index=ILCD)
LCIA_Nukos_FG_real.head()
# Out:
#                                                     Carbonation curing 1  \
# (ILCD 2.0 2018 midpoint, climate change, climat...             -0.000088
# (ILCD 2.0 2018 midpoint, climate change, climat...             -1.885915
# (ILCD 2.0 2018 midpoint, climate change, climat...             -0.000032
# (ILCD 2.0 2018 midpoint, climate change, climat...             -1.886035
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...             -0.001889
#
#                                                     Carbonation curing 2  \
# (ILCD 2.0 2018 midpoint, climate change, climat...              0.007698
# (ILCD 2.0 2018 midpoint, climate change, climat...             -0.438303
# (ILCD 2.0 2018 midpoint, climate change, climat...              0.002986
# (ILCD 2.0 2018 midpoint, climate change, climat...             -0.427618
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...              0.005874
#
#                                                     Carbonation curing 3  \
# (ILCD 2.0 2018 midpoint, climate change, climat...              0.000378
# (ILCD 2.0 2018 midpoint, climate change, climat...             -2.031934
# (ILCD 2.0 2018 midpoint, climate change, climat...              0.000138
# (ILCD 2.0 2018 midpoint, climate change, climat...             -2.031418
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...             -0.001859
#
#                                                     Carbonation mixing 1  \
# (ILCD 2.0 2018 midpoint, climate change, climat...             -0.387292
# (ILCD 2.0 2018 midpoint, climate change, climat...            -34.199404
# (ILCD 2.0 2018 midpoint, climate change, climat...             -0.120446
# (ILCD 2.0 2018 midpoint, climate change, climat...            -34.707141
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...             -0.457773
#
#                                                     Direct aqueous carbonation 1  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.003124
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -0.348858
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.001211
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -0.344523
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                      0.003339
#
#                                                     Direct aqueous carbonation 10  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.000099
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -2.550018
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.000033
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -2.550151
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                      -0.003384
#
#                                                     Direct aqueous carbonation 11  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.000124
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -2.738475
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.000043
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -2.738642
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                      -0.003804
#
#                                                     Direct aqueous carbonation 12  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.000110
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -2.405069
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.000038
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -2.405216
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                      -0.003072
#
#                                                     Direct aqueous carbonation 13  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.000158
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -2.637085
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.000056
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -2.637299
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                      -0.003596
#
#                                                     Direct aqueous carbonation 14  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.000114
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -2.308888
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.000040
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -2.309042
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                      -0.002869
#
#                                                     ...  \
# (ILCD 2.0 2018 midpoint, climate change, climat...  ...
# (ILCD 2.0 2018 midpoint, climate change, climat...  ...
# (ILCD 2.0 2018 midpoint, climate change, climat...  ...
# (ILCD 2.0 2018 midpoint, climate change, climat...  ...
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...  ...
#
#                                                     Indirect aqueous carbonation 5  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -0.027633
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -2.047089
# (ILCD 2.0 2018 midpoint, climate change, climat...                        0.000712
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -2.074010
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                       -0.021083
#
#                                                     Indirect aqueous carbonation 6  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -0.027935
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -2.156387
# (ILCD 2.0 2018 midpoint, climate change, climat...                        0.000594
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -2.183727
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                       -0.021434
#
#                                                     Indirect aqueous carbonation 7  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                        0.002387
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -0.392618
# (ILCD 2.0 2018 midpoint, climate change, climat...                        0.000936
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -0.389295
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                        0.003796
#
#                                                     Indirect aqueous carbonation 8  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                        0.008140
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -0.833561
# (ILCD 2.0 2018 midpoint, climate change, climat...                        0.002972
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -0.822449
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                        0.012630
#
#                                                     Indirect aqueous carbonation 9  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                        0.000160
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -0.137199
# (ILCD 2.0 2018 midpoint, climate change, climat...                        0.000083
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -0.136956
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                        0.004276
#
#                                                     Indirect solid carbonation 1  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.000983
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -1.317897
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.000379
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -1.316535
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                     -0.000525
#
#                                                     Indirect solid carbonation 2  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.001321
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -0.389358
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.000512
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -0.387525
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                      0.003092
#
#                                                     Indirect solid carbonation 3  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.000485
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -1.104485
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.000200
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -1.103800
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                      0.001191
#
#                                                     Indirect solid carbonation 4  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.001159
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -0.403609
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.000452
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -0.401998
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                      0.002355
#
#                                                     Indirect solid carbonation 5
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.007357
# (ILCD 2.0 2018 midpoint, climate change, climat...                      2.386406
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.002865
# (ILCD 2.0 2018 midpoint, climate change, climat...                      2.396627
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                      0.013688
#
# [5 rows x 34 columns]

# %%
results_ILCD = []
for m in ILCD:
    results_all_acts = getLCAresults(acts_Nukos, "Nukos_FG_opt", m) # total impact per tech
    results_ILCD.append(results_all_acts)
    
midpoint_methods_names = []
for m in ILCD:
    midpoint_methods_names.append(m)
    
LCIA_Nukos_FG_opt = pd.DataFrame(results_ILCD, index=ILCD)
LCIA_Nukos_FG_opt.head()
# Out:
#                                                     Carbonation curing 1  \
# (ILCD 2.0 2018 midpoint, climate change, climat...             -0.000088
# (ILCD 2.0 2018 midpoint, climate change, climat...             -1.885915
# (ILCD 2.0 2018 midpoint, climate change, climat...             -0.000032
# (ILCD 2.0 2018 midpoint, climate change, climat...             -1.886035
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...             -0.001889
#
#                                                     Carbonation curing 2  \
# (ILCD 2.0 2018 midpoint, climate change, climat...              0.007698
# (ILCD 2.0 2018 midpoint, climate change, climat...             -0.438303
# (ILCD 2.0 2018 midpoint, climate change, climat...              0.002986
# (ILCD 2.0 2018 midpoint, climate change, climat...             -0.427618
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...              0.005874
#
#                                                     Carbonation curing 3  \
# (ILCD 2.0 2018 midpoint, climate change, climat...              0.000378
# (ILCD 2.0 2018 midpoint, climate change, climat...             -2.031934
# (ILCD 2.0 2018 midpoint, climate change, climat...              0.000138
# (ILCD 2.0 2018 midpoint, climate change, climat...             -2.031418
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...             -0.001859
#
#                                                     Carbonation mixing 1  \
# (ILCD 2.0 2018 midpoint, climate change, climat...             -0.387292
# (ILCD 2.0 2018 midpoint, climate change, climat...            -34.199404
# (ILCD 2.0 2018 midpoint, climate change, climat...             -0.120446
# (ILCD 2.0 2018 midpoint, climate change, climat...            -34.707141
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...             -0.457773
#
#                                                     Direct aqueous carbonation 1  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -0.005682
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -6.267491
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -0.001955
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -6.275128
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                     -0.012785
#
#                                                     Direct aqueous carbonation 10  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.002527
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -3.433910
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.000884
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -3.437321
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                      -0.005239
#
#                                                     Direct aqueous carbonation 11  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.002843
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -3.728094
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.000994
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -3.731931
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                      -0.005881
#
#                                                     Direct aqueous carbonation 12  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.002312
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -3.206636
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.000809
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -3.209756
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                      -0.004754
#
#                                                     Direct aqueous carbonation 13  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.002717
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -3.568382
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.000951
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -3.572050
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                      -0.005550
#
#                                                     Direct aqueous carbonation 14  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.002162
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -3.054429
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -0.000757
# (ILCD 2.0 2018 midpoint, climate change, climat...                      -3.057349
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                      -0.004433
#
#                                                     ...  \
# (ILCD 2.0 2018 midpoint, climate change, climat...  ...
# (ILCD 2.0 2018 midpoint, climate change, climat...  ...
# (ILCD 2.0 2018 midpoint, climate change, climat...  ...
# (ILCD 2.0 2018 midpoint, climate change, climat...  ...
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...  ...
#
#                                                     Indirect aqueous carbonation 5  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -0.027633
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -2.047089
# (ILCD 2.0 2018 midpoint, climate change, climat...                        0.000712
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -2.074010
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                       -0.021083
#
#                                                     Indirect aqueous carbonation 6  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -0.027935
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -2.156387
# (ILCD 2.0 2018 midpoint, climate change, climat...                        0.000594
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -2.183727
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                       -0.021434
#
#                                                     Indirect aqueous carbonation 7  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -0.004953
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -5.362099
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -0.001703
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -5.368755
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                       -0.009724
#
#                                                     Indirect aqueous carbonation 8  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                        0.004315
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -2.199959
# (ILCD 2.0 2018 midpoint, climate change, climat...                        0.001633
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -2.194011
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                        0.009770
#
#                                                     Indirect aqueous carbonation 9  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -0.005069
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -2.489675
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -0.001785
# (ILCD 2.0 2018 midpoint, climate change, climat...                       -2.496528
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                       -0.002704
#
#                                                     Indirect solid carbonation 1  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -0.005263
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -5.510533
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -0.001867
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -5.517662
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                     -0.011943
#
#                                                     Indirect solid carbonation 2  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -0.004925
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -4.581994
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -0.001734
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -4.588652
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                     -0.008327
#
#                                                     Indirect solid carbonation 3  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -0.005790
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -5.375714
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -0.002056
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -5.383560
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                     -0.010418
#
#                                                     Indirect solid carbonation 4  \
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -0.005237
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -4.702307
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -0.001847
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -4.709391
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                     -0.009356
#
#                                                     Indirect solid carbonation 5
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.000732
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -2.065363
# (ILCD 2.0 2018 midpoint, climate change, climat...                      0.000483
# (ILCD 2.0 2018 midpoint, climate change, climat...                     -2.064147
# (ILCD 2.0 2018 midpoint, ecosystem quality, fre...                      0.001561
#
# [5 rows x 34 columns]

# %%
acts_diluted = []
acts_pure = []

for act in acts_Nukos:
    tech = fg_db_opt.get(act)
    for exc in tech.exchanges():
        if exc['input'][1] == 'Diluted CO2':
            acts_diluted.append(act)
        elif exc['input'][1] == 'Pure CO2':
            acts_pure.append(act)

# %%
LCIA_Nukos_pess = LCIA_Nukos_FG_pess.transpose()
LCIA_Nukos_pess = LCIA_Nukos_pess.unstack().reset_index()
LCIA_Nukos_pess['CO2 source'] = np.where(LCIA_Nukos_pess['level_1'].isin(acts_diluted), 'Diluted CO2', 'Pure CO2')
LCIA_Nukos_pess['level_1'] = LCIA_Nukos_pess.level_1.str[:-2]
LCIA_Nukos_pess['Scenario'] = 'Pessimistic'
LCIA_Nukos_real = LCIA_Nukos_FG_real.transpose()
LCIA_Nukos_real = LCIA_Nukos_real.unstack().reset_index()
LCIA_Nukos_real['CO2 source'] = np.where(LCIA_Nukos_real['level_1'].isin(acts_diluted), 'Diluted CO2', 'Pure CO2')
LCIA_Nukos_real['level_1'] = LCIA_Nukos_real.level_1.str[:-2]
LCIA_Nukos_real['Scenario'] = 'Realisitc'
LCIA_Nukos_opt = LCIA_Nukos_FG_opt.transpose()
LCIA_Nukos_opt = LCIA_Nukos_opt.unstack().reset_index()
LCIA_Nukos_opt['CO2 source'] = np.where(LCIA_Nukos_opt['level_1'].isin(acts_diluted), 'Diluted CO2', 'Pure CO2')
LCIA_Nukos_opt['level_1'] = LCIA_Nukos_opt.level_1.str[:-2]
LCIA_Nukos_opt['Scenario'] = 'Optimistic'
frames = [LCIA_Nukos_pess, LCIA_Nukos_real, LCIA_Nukos_opt]
LCIA_Nukos = pd.concat(frames, ignore_index=True)
LCIA_Nukos = LCIA_Nukos.rename(columns={"level_0": "Impact Category", "level_1": "Route", 0: 'Impact'})
LCIA_Nukos['Route'] = LCIA_Nukos['Route'].apply(lambda x: str(x).rstrip())
LCIA_Nukos
# Out:
#                                         Impact Category  \
# 0     (ILCD 2.0 2018 midpoint, climate change, clima...
# 1     (ILCD 2.0 2018 midpoint, climate change, clima...
# 2     (ILCD 2.0 2018 midpoint, climate change, clima...
# 3     (ILCD 2.0 2018 midpoint, climate change, clima...
# 4     (ILCD 2.0 2018 midpoint, climate change, clima...
# ...                                                 ...
# 1933  (ILCD 2.0 2018 midpoint, resources, minerals a...
# 1934  (ILCD 2.0 2018 midpoint, resources, minerals a...
# 1935  (ILCD 2.0 2018 midpoint, resources, minerals a...
# 1936  (ILCD 2.0 2018 midpoint, resources, minerals a...
# 1937  (ILCD 2.0 2018 midpoint, resources, minerals a...
#
#                            Route    Impact   CO2 source     Scenario
# 0             Carbonation curing -0.000088     Pure CO2  Pessimistic
# 1             Carbonation curing  0.007698     Pure CO2  Pessimistic
# 2             Carbonation curing  0.000378     Pure CO2  Pessimistic
# 3             Carbonation mixing -0.387292     Pure CO2  Pessimistic
# 4     Direct aqueous carbonation  0.003124     Pure CO2  Pessimistic
# ...                          ...       ...          ...          ...
# 1933  Indirect solid carbonation -0.000057     Pure CO2   Optimistic
# 1934  Indirect solid carbonation -0.000054     Pure CO2   Optimistic
# 1935  Indirect solid carbonation -0.000059     Pure CO2   Optimistic
# 1936  Indirect solid carbonation -0.000059  Diluted CO2   Optimistic
# 1937  Indirect solid carbonation -0.000059  Diluted CO2   Optimistic
#
# [1938 rows x 5 columns]

# %%
LCIA_Nukos_grouped = LCIA_Nukos.groupby(['Impact Category', 'Route', 'Scenario']).agg({'Impact': ['median']})
name = 'LCIA_median.xlsx'
writer = pd.ExcelWriter(name, engine='xlsxwriter')
LCIA_Nukos_grouped.to_excel(writer, sheet_name = 'Median')
writer.save()

# %%
method = ILCD[3]
method
# Out:
# ('ILCD 2.0 2018 midpoint', 'climate change', 'climate change total')

# %%
method = ILCD[3]

LCIA_Nukos_reduced = LCIA_Nukos.loc[LCIA_Nukos['Impact Category'] ==
                                ('ILCD 2.0 2018 midpoint', 'climate change', 'climate change total')]
LCIA_Nukos_reduced = LCIA_Nukos_reduced[(LCIA_Nukos_reduced['Route'] == 'Direct aqueous carbonation') |
                                        (LCIA_Nukos_reduced['Route'] == 'Indirect aqueous carbonation') | 
                                        (LCIA_Nukos_reduced['Route'] == 'Indirect solid carbonation') |
                                        (LCIA_Nukos_reduced['Route'] == 'Carbonation curing')]
plt.style.use('ggplot')
plt.figure(figsize=(10,5))

max_width = 15
ax = sns.boxplot(x="Route", y="Impact",
            hue="Scenario",
            data=LCIA_Nukos_reduced)
ax.set(ylabel=r'kg CO$_2$-eq./kg CO$_2$ used')
ax.set_xticklabels(textwrap.fill(x.get_text(), max_width) for x in ax.get_xticklabels())
sns.despine(offset=10, trim=True)

plt.savefig("Boxplot/Boxplot_GWI_for_publication.tiff", dpi = 300, bbox_inches='tight')

# %%
#differentiation among the CO2 source
method = ILCD[3]

LCIA_Nukos_reduced = LCIA_Nukos.loc[LCIA_Nukos['Impact Category'] ==
                                ('ILCD 2.0 2018 midpoint', 'climate change', 'climate change total')]
LCIA_Nukos_reduced = LCIA_Nukos_reduced[(LCIA_Nukos_reduced['Route'] == 'Direct aqueous carbonation') |
                                        (LCIA_Nukos_reduced['Route'] == 'Indirect solid carbonation')]
plt.style.use('ggplot')

max_width = 15
ax = sns.catplot(x="Route", y="Impact",
            hue="CO2 source", col="Scenario", kind = "box",
            data=LCIA_Nukos_reduced, legend_out = False)
(ax.set_axis_labels("", r"Climate change kg CO$_2$-eq./kg CO$_2$ used")
  .set_titles("{col_name}")
  .despine(left=True))
ax._legend.set_title(r"$CO_2$ Source")
new_labels = [r'Pure CO$_2$', r'Diluted $CO_2$']
for t, l in zip(ax._legend.texts, new_labels): t.set_text(l)

plt.savefig("Boxplot/Boxplot_CO2_source.tiff", dpi = 300, bbox_inches='tight')

# %%
for m in ILCD: 
    LCIA_Nukos_reduced = LCIA_Nukos.loc[LCIA_Nukos['Impact Category'] == m]
    LCIA_Nukos_reduced = LCIA_Nukos_reduced[(LCIA_Nukos_reduced['Route'] == 'Direct aqueous carbonation') |
                                            (LCIA_Nukos_reduced['Route'] == 'Indirect aqueous carbonation') | 
                                            (LCIA_Nukos_reduced['Route'] == 'Indirect solid carbonation') |
                                            (LCIA_Nukos_reduced['Route'] == 'Carbonation curing')]
    IC_name = m[2].capitalize().replace(' ', '_')
    plt.style.use('ggplot')
    max_width = 15
    ax = sns.boxplot(x="Route", y="Impact",
                hue="Scenario",
                data=LCIA_Nukos_reduced)
    ax.set(ylabel=m[2].capitalize() + ' [' + methods[m]['unit'] + ']')
    ax.set_xticklabels(textwrap.fill(x.get_text(), max_width) for x in ax.get_xticklabels())
    sns.despine(offset=10, trim=True)
    plt.savefig("Boxplot/Boxplot_" + IC_name + "_grouped.png", dpi = 300, bbox_inches='tight')
    plt.clf()

# %%
name = 'LCIA.xlsx'
writer = pd.ExcelWriter(name, engine='xlsxwriter')
LCIA_Nukos_FG_pess.to_excel(writer, sheet_name = 'Nukos_FG_pess')
LCIA_Nukos_FG_real.to_excel(writer, sheet_name = 'Nukos_FG_real')
LCIA_Nukos_FG_opt.to_excel(writer, sheet_name = 'Nukos_FG_opt')
writer.save()

# %%
LCIAs = {'LCIA_Nukos_FG_pess': LCIA_Nukos_FG_pess,
         'LCIA_Nukos_FG_real': LCIA_Nukos_FG_real,
         'LCIA_Nukos_FG_opt': LCIA_Nukos_FG_opt}
i = 0

for key, value in LCIAs.items():
    for i in range(len(ILCD)): 
        data = value.iloc[i].drop('Carbonation mixing 1')
        IC = value.iloc[i].name
        xlabel_IC = IC[1].capitalize() + ' [' + methods[IC]['unit'] + ']'
        IC_name = IC[1].capitalize().replace(' ', '_')


        #xlocations = np.array(range(len(data))) + 0.5
        #width = 0.5

        plt.style.use('ggplot')
        fig, ax = plt.subplots(figsize=(8, 8))
        ax.barh(data.index, data)
        ax.set(xlabel = xlabel_IC)
        plt.rc('ytick', labelsize = 10)
        plt.rc('xtick', labelsize = 10)
        plt.savefig(key + '/Mineral_Carbonation_' + IC_name + '.png', bbox_inches='tight')
        i += 1
# Out:
# C:\Users\niltho\AppData\Local\Temp/ipykernel_9828/1696734050.py:18: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(8, 8))

# %%
def doCAcalc(myact, mydemand, mymethod):
    my_fu = {myact: mydemand} 
    lca = LCA(my_fu, mymethod)
    lca.lci()
    lca.lcia()
    return lca.score

def getCAresults(acts, mydemand, mymethod):
    all_activities = []
    results = []
    bio_keys_list = []
    bio_list = list(lca.biosphere_dict.keys())
    i = 0
    for exc in bio_list:
        bio_keys_list.append(list(lca.biosphere_dict.keys())[i][1])
        i = i + 1
    a = 0
    while a < len(acts):
        if acts[a] in bio_keys_list: #guardian pattern needs to be improved in a further version as direct emissions are not calculated
            break
        elif acts[a] in [act['name'] for act in fg_db_opt or act in fg_db_pess or act in fg_db_real]:
            break
        elif acts[a] in [act['name'] for act in bg_db]:
            act = bg_db.get(acts[a])
        else:
            act = eidb.get(acts[a])
        all_activities.append(act['name'])
        results.append(doCAcalc(act, mydemand[a], mymethod)) # 1 stays for one unit of each process
        a += 1
     
    results_dict = list(zip(all_activities, results))
    
    return results_dict

# %%
tech = fg_db_opt.get('Carbonation curing 3')
act_CA = []
value_CA = []
fu = []
for i in [exc for exc in tech.exchanges() if exc['type'] == 'technosphere' or exc['type'] == 'biosphere']:  # Epxlore the activity as usual
    act_CA.append(i['input'][1])
    value_CA.append(i['amount'])
fu = list(zip(act_CA, value_CA))
print(fu)

results_CA = getCAresults(act_CA, value_CA, mymethod)
results_LCIA = sum(x[1] for x in results_CA)
print('Total: ' + str(results_LCIA))
results_CA
# Out:
# [('Pure CO2', 1.0), ('AOD-slag', 5.2), ('Heat', 2.456470588235294), ('Electricity', 0.31764705882352945), ('Water', 1.1529411764705884), ('Sand', 5.2), ('PC-based blocks', -11.105882352941178), ('Grey Water', 0.9294117647058824)]
# Total: -2.031417829653666
# [('Pure CO2', -0.8711874940225087),
#  ('AOD-slag', 0.0),
#  ('Heat', 0.2567137589033672),
#  ('Electricity', 0.13001214287038898),
#  ('Water', 0.0003966140861598981),
#  ('Sand', 0.059580498359456904),
#  ('PC-based blocks', -1.6072170948838496),
#  ('Grey Water', 0.00028374503331954966)]

# %%
mymethod = ILCD[3]

labels = [r'Pure CO$_2$',
          'AOD-slag',
          'Heat',
          'Electricity',
          'Water',
          'Sand',
          'PC-based blocks',
          'Grey Water']
data = [result[1] for result in results_CA]

plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(8, 4))
ax.barh(labels, data)
ax.set(xlabel= r'kg CO$_2$-eq./kg CO$_2$ used', ylabel= tech['name'])
plt.rc('ytick', labelsize = 12)
plt.rc('xtick', labelsize = 12);
plt.savefig('CA_Carbonation_curing_3.tiff', dpi=300, bbox_inches='tight')

# %%
writer = pd.ExcelWriter("Contribution_Analysis.xlsx", engine='xlsxwriter')
for act in acts_Nukos:
    act_CA = []
    value_CA = []
    tech = fg_db_real.get(act)
    for i in [exc for exc in tech.exchanges() if exc['type'] == 'technosphere' or exc['type'] == 'biosphere']:  # Epxlore the activity as usual
        act_CA.append(i['input'][1])
        value_CA.append(i['amount'])
    results_CA = getCAresults(act_CA, value_CA, mymethod)
    my_output3 = pd.DataFrame(results_CA, columns=['Process', 'Impact']).set_index('Process')
    total = my_output3.sum()
    total.name = 'Total'
    my_output3 = my_output3.append(total.transpose())
    my_output3.to_excel(writer, sheet_name = tech['name'])
    print(tech)
writer.save()
# Out:
# 'Carbonation curing 1' (kilogram, None, None)
# 'Carbonation curing 2' (kilogram, None, None)
# 'Carbonation curing 3' (kilogram, None, None)
# 'Carbonation mixing 1' (kilogram, None, None)
# 'Direct aqueous carbonation 1' (kilogram, None, None)
# 'Direct aqueous carbonation 10' (kilogram, None, None)
# 'Direct aqueous carbonation 11' (kilogram, None, None)
# 'Direct aqueous carbonation 12' (kilogram, None, None)
# 'Direct aqueous carbonation 13' (kilogram, None, None)
# 'Direct aqueous carbonation 14' (kilogram, None, None)
# 'Direct aqueous carbonation 15' (kilogram, None, None)
# 'Direct aqueous carbonation 2' (kilogram, None, None)
# 'Direct aqueous carbonation 3' (kilogram, None, None)
# 'Direct aqueous carbonation 4' (kilogram, None, None)
# 'Direct aqueous carbonation 5' (kilogram, None, None)
# 'Direct aqueous carbonation 6' (kilogram, None, None)
# 'Direct aqueous carbonation 7' (kilogram, None, None)
# 'Direct aqueous carbonation 8' (kilogram, None, None)
# 'Direct aqueous carbonation 9' (kilogram, None, None)
# 'Indirect aqueous carbonation 1' (kilogram, None, None)
# 'Indirect aqueous carbonation 10' (kilogram, None, None)
# 'Indirect aqueous carbonation 2' (kilogram, None, None)
# 'Indirect aqueous carbonation 3' (kilogram, None, None)
# 'Indirect aqueous carbonation 4' (kilogram, None, None)
# 'Indirect aqueous carbonation 5' (kilogram, None, None)
# 'Indirect aqueous carbonation 6' (kilogram, None, None)
# 'Indirect aqueous carbonation 7' (kilogram, None, None)
# 'Indirect aqueous carbonation 8' (kilogram, None, None)
# 'Indirect aqueous carbonation 9' (kilogram, None, None)
# 'Indirect solid carbonation 1' (kilogram, None, None)
# 'Indirect solid carbonation 2' (kilogram, None, None)
# 'Indirect solid carbonation 3' (kilogram, None, None)
# 'Indirect solid carbonation 4' (kilogram, None, None)
# 'Indirect solid carbonation 5' (kilogram, None, None)

# %%
#name_CA_multi = 'CA_Results_' + current_tech + '_' + "".join(mymethod[1].replace(' ', '_')) + '.xlsx'
writer = pd.ExcelWriter("Contribution Analysis.xlsx", engine='xlsxwriter')
for act in acts_Nukos:
    act_CA = []
    value_CA = []
    tech = fg_db_real.get(act)
    for i in [exc for exc in tech.exchanges() if exc['type'] == 'technosphere' or exc['type'] == 'biosphere']:  # Epxlore the activity as usual
        act_CA.append(i['input'][1])
        value_CA.append(i['amount'])
    results_CA = getCAresults(act_CA, value_CA, mymethod)
    labels = [label[0] for label in results_CA]
    data = [result[1] for result in results_CA]
    plt.style.use('ggplot')
    fig, ax = plt.subplots(figsize=(8, 4))
    ax.barh(labels, data)
    ax.set(xlabel= methods[mymethod]["unit"], ylabel= tech['name'])
    plt.title(mymethod[1].capitalize())
    plt.rc('ytick', labelsize = 12)
    plt.rc('xtick', labelsize = 12);
    plt.savefig('CA_' + tech['name'] + '.png', bbox_inches='tight')
# Out:
# C:\Users\niltho\AppData\Local\Temp/ipykernel_9828/3173619050.py:14: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(8, 4))
